# %% [markdown]
# <a href="https://colab.research.google.com/github/AlmudenaGarciaGarcia/Trabajo-Practico---Visualizacion/blob/master/TrabajoPractico_AlmudenaGarciaGarcia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Trabajo Practico - Visualización de Datos
# **Nombre:** Almudena García García\
# **Google Colab:** https://colab.research.google.com/drive/1pcug3oGlJzfws1yBdgGlnVG3WWzt3FFn?usp=sharing

# %%
# carga de datos
import pandas as pd
import io
from google.colab import files
# manipulación y visualización
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns

# %%
import pandas as pd
url="https://raw.githubusercontent.com/AlmudenaGarciaGarcia/Trabajo-Practico---Visualizacion/master/listings_detailed_coordenadas.csv"
df = pd.read_csv(url)
df["latitude"] = pd.to_numeric(df["latitude"])
df=pd.DataFrame(df)

# %%
df
# Out:
#                                               name  latitude  longitude
# 0         Rooftop terrace room -  ensuite bathroom  40.45724   -3.67688
# 1                             Bright and airy room  40.40381   -3.74130
# 2                Apartmento Arganzuela- Madrid Rio  40.38840   -3.69511
# 3                           Gran Via Studio Madrid  40.42183   -3.70529
# 4               Single Room whith private Bathroom  40.38975   -3.69018
# ...                                            ...       ...        ...
# 19613    Habitación con TV con Netflix en Lavapiés  40.40756   -3.69937
# 19614  Habitación con TV con Netflix en Gaztambide  40.43706   -3.71364
# 19615    Habitación con TV con Netflix en Chamberí  40.43857   -3.70715
# 19616        Habitación con TV con Netflix en Goya  40.43027   -3.66759
# 19617    Habitación con TV con Netflix en Chamberí  40.43484   -3.70667
#
# [19618 rows x 3 columns]

# %%
import folium

world_map = folium.Map(location =[40.4165, -3.70256], tiles='stamenterrain', zoom_start=12,prefer_canvas=True)
for i in df.index: #representaremos los 100 primeros
  try:
    if(i<500):
      folium.Marker([df["latitude"][i], df["longitude"][i]], # lat lon
                  tooltip=df["name"][i],
                  icon=folium.Icon(icon='home', color='purple')
                ).add_to(world_map)
  except:
    pass
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=true; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
